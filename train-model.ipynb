# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 16.7 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import torch
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from ultralytics import YOLO

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# /kaggle/input/cityperson/README.dataset.txt
# /kaggle/input/cityperson/README.roboflow.txt
# /kaggle/input/cityperson/data.yaml
# /kaggle/input/cityperson/valid/labels/frankfurt_000001_005410_leftImg8bit_png.rf.d2f574ab88244b1d99379928be563708.txt
# /kaggle/input/cityperson/valid/labels/munster_000156_000019_leftImg8bit_png.rf.a42fb3016284e16c66d3981acf973e78.txt
# /kaggle/input/cityperson/valid/labels/frankfurt_000000_009688_leftImg8bit_png.rf.55e3116cee977c57bed6c3d3b83681a3.txt
# /kaggle/input/cityperson/valid/labels/munster_000017_000019_leftImg8bit_png.rf.567c8e5ff8beabcdc8daaf7e5e6040be.txt
# ...

# %%
print(torch.cuda.is_available())  # Doit retourner True si CUDA est disponible
print(torch.cuda.device_count())  # Nombre de GPUs disponibles
print(torch.cuda.get_device_name(0))  # Nom du GPU (si disponible)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# True
# 2
# Tesla T4
# device(type='cuda')

# %%
model = YOLO('yolov8n.pt').to(device)  # Load model
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 80.9MB/s]

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/kaggle/input/cityperson/data.yaml epochs=200 imgsz=640 batch=16 device=0
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...
